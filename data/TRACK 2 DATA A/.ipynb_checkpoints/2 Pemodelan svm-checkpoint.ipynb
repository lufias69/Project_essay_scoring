# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from joblib import dump
import numpy as np
from sklearn import svm
import time

# %%
data = pd.read_excel('data/Data_B_Bersih_2.xlsx')
label = data['skor1']
# y = [str(x) for x in label]
respon = data['respon'].tolist()
# respon
y = np.array(label)
# data

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(respon)
save_ = vectorizer.fit(respon)
# print(vectorizer.get_feature_names())
dump(save_, 'model/tfdf_B.joblib')
# Out:
# ['model/tfdf_B.joblib']

# %%
K = 10 #pembagian data uji dan data latih
# from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score #, precision_score, recall_score
# kf= KFold(n_splits=K) 
skf = StratifiedKFold(n_splits=K,random_state=2, shuffle=True)
skf
# Out:
# StratifiedKFold(n_splits=10, random_state=2, shuffle=True)

# %%
# K = 10 #pembagian data uji dan data latih
# from sklearn.model_selection import KFold
# from sklearn.metrics import accuracy_score

# kf = KFold(n_splits=K) 
C_range = np.arange(1.0,5,0.1)
gamma_range = np.arange(0.1,2, 0.1)

C_range_ = []
gamma_range_ = []
rerata_akurasi_svm = []
rerata_waktu_eksekusi = []
rerata_waktu_prediksi = []
count=0
for i in range(len(C_range)):
    for j in range(len(gamma_range)):
        C = C_range[i]
        gamma = gamma_range[j]
        akurasi_svm = []
        waktu_eksekusi = []
        waktu_prediksi = []
        cSVM = svm.SVC(kernel='rbf', gamma=gamma, C=C) #model
        for train_index, test_index in skf.split(X, y):
#             print(train_index)
            #membagi data latih dan data uji
            X_train, X_test = X[train_index], X[test_index]
#             print(train_index)
            y_train = y[train_index]
            y_test  = y[test_index]
            
            start = time.time()
            #Melatih Model
            cSVM = cSVM.fit(X_train, y_train) #SVM
            end = time.time()
            waktu_eksekusi.append(end-start)
            
            #proses prediksi
            start = time.time()
            P_SVM = cSVM.predict(X_test)
            end = time.time()
            waktu_prediksi.append(end-start)
            
            akurasi_svm.append(accuracy_score(y_test, P_SVM))
        print("iterasi ke-", count)
        C_range_.append(C)
        gamma_range_.append(gamma)
        
        rr = sum(akurasi_svm)/len(akurasi_svm)
        rerata_akurasi_svm.append(rr)
        count+=1
        
        rerata_waktu_eksekusi.append(sum(waktu_eksekusi)/len(waktu_eksekusi))
        rerata_waktu_prediksi.append(sum(waktu_prediksi)/len(waktu_prediksi))
        
        #Menampilkan hasil 
        print("-"*30)
        print("C     : ", C)
        print("gamma : ", gamma)
        print("-"*20)
        print("Rata-rata Akurasi SVM : %0.2f" % (sum(akurasi_svm)/len(akurasi_svm)))
        print("Rata-rata Waktu eksekusi SVM: %0.2f" % (sum(waktu_eksekusi)/len(waktu_eksekusi)))
        print("Rata-rata Waktu prediksi  SVM: %0.2f" % (sum(waktu_prediksi)/len(waktu_prediksi)))
        print("="*30)
    
#proses mencari parameter dan akurasi terbaik
x = max(rerata_akurasi_svm)
#al = list(alpha_range)
index = rerata_akurasi_svm.index(x)
round(gamma_range_[index],2)
print("---------------------------")
print("gamma terbaik adalah :", round(gamma_range_[index],2))
print("    C terbaik adalah :", round(C_range_[index],2))
print("             Akurasi :", round(x, 2))

#MENYIMPAN HASIL
dict_komentar  = {"gamma":gamma_range_,"c":C_range_, "akurasi":rerata_akurasi_svm, "waktu eksekusi":rerata_waktu_eksekusi, "waktu prediksi":rerata_waktu_prediksi}
df = pd.DataFrame(dict_komentar,columns = ["gamma", 'c', "akurasi", "waktu eksekusi", "waktu prediksi"])
writer = pd.ExcelWriter('data/parameter/parameter-akurasi-svm.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='svm-parameter')
#Close the Pandas Excel writer and output the Excel file.
writer.save()
# Out:
# iterasi ke- 0
# ------------------------------
# C     :  1.0
# gamma :  0.1
# --------------------
# Rata-rata Akurasi SVM : 0.57
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 1
# ------------------------------
# C     :  1.0
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.61
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 2
# ------------------------------
# C     :  1.0
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.61
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 3
# ------------------------------
# C     :  1.0
# gamma :  0.4
# --------------------
# Rata-rata Akurasi SVM : 0.62
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 4
# ------------------------------
# C     :  1.0
# gamma :  0.5
# --------------------
# Rata-rata Akurasi SVM : 0.65
# Rata-rata Waktu eksekusi SVM: 0.01
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 5
# ------------------------------
# C     :  1.0
# gamma :  0.6
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 6
# ------------------------------
# C     :  1.0
# gamma :  0.7000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 7
# ------------------------------
# C     :  1.0
# gamma :  0.8
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 8
# ------------------------------
# C     :  1.0
# gamma :  0.9
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 9
# ------------------------------
# C     :  1.0
# gamma :  1.0
# --------------------
# Rata-rata Akurasi SVM : 0.67
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 10
# ------------------------------
# C     :  1.0
# gamma :  1.1
# --------------------
# Rata-rata Akurasi SVM : 0.67
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 11
# ------------------------------
# C     :  1.0
# gamma :  1.2000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.67
# Rata-rata Waktu eksekusi SVM: 0.01
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 12
# ------------------------------
# C     :  1.0
# gamma :  1.3000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.01
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 13
# ------------------------------
# C     :  1.0
# gamma :  1.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.65
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 14
# ------------------------------
# C     :  1.0
# gamma :  1.5000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.63
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 15
# ------------------------------
# C     :  1.0
# gamma :  1.6
# --------------------
# Rata-rata Akurasi SVM : 0.61
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 16
# ------------------------------
# C     :  1.0
# gamma :  1.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.62
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 17
# ------------------------------
# C     :  1.0
# gamma :  1.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.61
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 18
# ------------------------------
# C     :  1.0
# gamma :  1.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.61
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 19
# ------------------------------
# C     :  1.1
# gamma :  0.1
# --------------------
# Rata-rata Akurasi SVM : 0.57
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 20
# ------------------------------
# C     :  1.1
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.61
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 21
# ------------------------------
# C     :  1.1
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.62
# Rata-rata Waktu eksekusi SVM: 0.01
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 22
# ------------------------------
# C     :  1.1
# gamma :  0.4
# --------------------
# Rata-rata Akurasi SVM : 0.65
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 23
# ------------------------------
# C     :  1.1
# gamma :  0.5
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 24
# ------------------------------
# C     :  1.1
# gamma :  0.6
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 25
# ------------------------------
# C     :  1.1
# gamma :  0.7000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 26
# ------------------------------
# C     :  1.1
# gamma :  0.8
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 27
# ------------------------------
# C     :  1.1
# gamma :  0.9
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 28
# ------------------------------
# C     :  1.1
# gamma :  1.0
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 29
# ------------------------------
# C     :  1.1
# gamma :  1.1
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 30
# ------------------------------
# C     :  1.1
# gamma :  1.2000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 31
# ------------------------------
# C     :  1.1
# gamma :  1.3000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 32
# ------------------------------
# C     :  1.1
# gamma :  1.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 33
# ------------------------------
# C     :  1.1
# gamma :  1.5000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.67
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 34
# ------------------------------
# C     :  1.1
# gamma :  1.6
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 35
# ------------------------------
# C     :  1.1
# gamma :  1.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.01
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 36
# ------------------------------
# C     :  1.1
# gamma :  1.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.65
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 37
# ------------------------------
# C     :  1.1
# gamma :  1.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.63
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 38
# ------------------------------
# C     :  1.2000000000000002
# gamma :  0.1
# --------------------
# Rata-rata Akurasi SVM : 0.58
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 39
# ------------------------------
# C     :  1.2000000000000002
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.61
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 40
# ------------------------------
# C     :  1.2000000000000002
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.63
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 41
# ------------------------------
# C     :  1.2000000000000002
# gamma :  0.4
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 42
# ------------------------------
# C     :  1.2000000000000002
# gamma :  0.5
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 43
# ------------------------------
# C     :  1.2000000000000002
# gamma :  0.6
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 44
# ------------------------------
# C     :  1.2000000000000002
# gamma :  0.7000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 45
# ------------------------------
# C     :  1.2000000000000002
# gamma :  0.8
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 46
# ------------------------------
# C     :  1.2000000000000002
# gamma :  0.9
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.01
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 47
# ------------------------------
# C     :  1.2000000000000002
# gamma :  1.0
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.01
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 48
# ------------------------------
# C     :  1.2000000000000002
# gamma :  1.1
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 49
# ------------------------------
# C     :  1.2000000000000002
# gamma :  1.2000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 50
# ------------------------------
# C     :  1.2000000000000002
# gamma :  1.3000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 51
# ------------------------------
# C     :  1.2000000000000002
# gamma :  1.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 52
# ------------------------------
# C     :  1.2000000000000002
# gamma :  1.5000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 53
# ------------------------------
# C     :  1.2000000000000002
# gamma :  1.6
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 54
# ------------------------------
# C     :  1.2000000000000002
# gamma :  1.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 55
# ------------------------------
# C     :  1.2000000000000002
# gamma :  1.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 56
# ------------------------------
# C     :  1.2000000000000002
# gamma :  1.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.67
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 57
# ------------------------------
# C     :  1.3000000000000003
# gamma :  0.1
# --------------------
# Rata-rata Akurasi SVM : 0.58
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 58
# ------------------------------
# C     :  1.3000000000000003
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.61
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 59
# ------------------------------
# C     :  1.3000000000000003
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.65
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 60
# ------------------------------
# C     :  1.3000000000000003
# gamma :  0.4
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 61
# ------------------------------
# C     :  1.3000000000000003
# gamma :  0.5
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 62
# ------------------------------
# C     :  1.3000000000000003
# gamma :  0.6
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 63
# ------------------------------
# C     :  1.3000000000000003
# gamma :  0.7000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 64
# ------------------------------
# C     :  1.3000000000000003
# gamma :  0.8
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 65
# ------------------------------
# C     :  1.3000000000000003
# gamma :  0.9
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 66
# ------------------------------
# C     :  1.3000000000000003
# gamma :  1.0
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 67
# ------------------------------
# C     :  1.3000000000000003
# gamma :  1.1
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 68
# ------------------------------
# C     :  1.3000000000000003
# gamma :  1.2000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 69
# ------------------------------
# C     :  1.3000000000000003
# gamma :  1.3000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 70
# ------------------------------
# C     :  1.3000000000000003
# gamma :  1.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 71
# ------------------------------
# C     :  1.3000000000000003
# gamma :  1.5000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 72
# ------------------------------
# C     :  1.3000000000000003
# gamma :  1.6
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 73
# ------------------------------
# C     :  1.3000000000000003
# gamma :  1.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 74
# ------------------------------
# C     :  1.3000000000000003
# gamma :  1.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 75
# ------------------------------
# C     :  1.3000000000000003
# gamma :  1.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 76
# ------------------------------
# C     :  1.4000000000000004
# gamma :  0.1
# --------------------
# Rata-rata Akurasi SVM : 0.59
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 77
# ------------------------------
# C     :  1.4000000000000004
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.62
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 78
# ------------------------------
# C     :  1.4000000000000004
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 79
# ------------------------------
# C     :  1.4000000000000004
# gamma :  0.4
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 80
# ------------------------------
# C     :  1.4000000000000004
# gamma :  0.5
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 81
# ------------------------------
# C     :  1.4000000000000004
# gamma :  0.6
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 82
# ------------------------------
# C     :  1.4000000000000004
# gamma :  0.7000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 83
# ------------------------------
# C     :  1.4000000000000004
# gamma :  0.8
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 84
# ------------------------------
# C     :  1.4000000000000004
# gamma :  0.9
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 85
# ------------------------------
# C     :  1.4000000000000004
# gamma :  1.0
# --------------------
# Rata-rata Akurasi SVM : 0.72
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 86
# ------------------------------
# C     :  1.4000000000000004
# gamma :  1.1
# --------------------
# Rata-rata Akurasi SVM : 0.73
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 87
# ------------------------------
# C     :  1.4000000000000004
# gamma :  1.2000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 88
# ------------------------------
# C     :  1.4000000000000004
# gamma :  1.3000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 89
# ------------------------------
# C     :  1.4000000000000004
# gamma :  1.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 90
# ------------------------------
# C     :  1.4000000000000004
# gamma :  1.5000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 91
# ------------------------------
# C     :  1.4000000000000004
# gamma :  1.6
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 92
# ------------------------------
# C     :  1.4000000000000004
# gamma :  1.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 93
# ------------------------------
# C     :  1.4000000000000004
# gamma :  1.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 94
# ------------------------------
# C     :  1.4000000000000004
# gamma :  1.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 95
# ------------------------------
# C     :  1.5000000000000004
# gamma :  0.1
# --------------------
# Rata-rata Akurasi SVM : 0.60
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 96
# ------------------------------
# C     :  1.5000000000000004
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.63
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 97
# ------------------------------
# C     :  1.5000000000000004
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 98
# ------------------------------
# C     :  1.5000000000000004
# gamma :  0.4
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 99
# ------------------------------
# C     :  1.5000000000000004
# gamma :  0.5
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 100
# ------------------------------
# C     :  1.5000000000000004
# gamma :  0.6
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 101
# ------------------------------
# C     :  1.5000000000000004
# gamma :  0.7000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 102
# ------------------------------
# C     :  1.5000000000000004
# gamma :  0.8
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 103
# ------------------------------
# C     :  1.5000000000000004
# gamma :  0.9
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.01
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 104
# ------------------------------
# C     :  1.5000000000000004
# gamma :  1.0
# --------------------
# Rata-rata Akurasi SVM : 0.72
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 105
# ------------------------------
# C     :  1.5000000000000004
# gamma :  1.1
# --------------------
# Rata-rata Akurasi SVM : 0.72
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 106
# ------------------------------
# C     :  1.5000000000000004
# gamma :  1.2000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 107
# ------------------------------
# C     :  1.5000000000000004
# gamma :  1.3000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 108
# ------------------------------
# C     :  1.5000000000000004
# gamma :  1.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 109
# ------------------------------
# C     :  1.5000000000000004
# gamma :  1.5000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 110
# ------------------------------
# C     :  1.5000000000000004
# gamma :  1.6
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 111
# ------------------------------
# C     :  1.5000000000000004
# gamma :  1.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 112
# ------------------------------
# C     :  1.5000000000000004
# gamma :  1.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 113
# ------------------------------
# C     :  1.5000000000000004
# gamma :  1.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 114
# ------------------------------
# C     :  1.6000000000000005
# gamma :  0.1
# --------------------
# Rata-rata Akurasi SVM : 0.61
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 115
# ------------------------------
# C     :  1.6000000000000005
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.64
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 116
# ------------------------------
# C     :  1.6000000000000005
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 117
# ------------------------------
# C     :  1.6000000000000005
# gamma :  0.4
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 118
# ------------------------------
# C     :  1.6000000000000005
# gamma :  0.5
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 119
# ------------------------------
# C     :  1.6000000000000005
# gamma :  0.6
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 120
# ------------------------------
# C     :  1.6000000000000005
# gamma :  0.7000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 121
# ------------------------------
# C     :  1.6000000000000005
# gamma :  0.8
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 122
# ------------------------------
# C     :  1.6000000000000005
# gamma :  0.9
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 123
# ------------------------------
# C     :  1.6000000000000005
# gamma :  1.0
# --------------------
# Rata-rata Akurasi SVM : 0.72
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 124
# ------------------------------
# C     :  1.6000000000000005
# gamma :  1.1
# --------------------
# Rata-rata Akurasi SVM : 0.73
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 125
# ------------------------------
# C     :  1.6000000000000005
# gamma :  1.2000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.72
# Rata-rata Waktu eksekusi SVM: 0.01
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 126
# ------------------------------
# C     :  1.6000000000000005
# gamma :  1.3000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 127
# ------------------------------
# C     :  1.6000000000000005
# gamma :  1.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 128
# ------------------------------
# C     :  1.6000000000000005
# gamma :  1.5000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 129
# ------------------------------
# C     :  1.6000000000000005
# gamma :  1.6
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 130
# ------------------------------
# C     :  1.6000000000000005
# gamma :  1.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 131
# ------------------------------
# C     :  1.6000000000000005
# gamma :  1.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 132
# ------------------------------
# C     :  1.6000000000000005
# gamma :  1.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 133
# ------------------------------
# C     :  1.7000000000000006
# gamma :  0.1
# --------------------
# Rata-rata Akurasi SVM : 0.61
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 134
# ------------------------------
# C     :  1.7000000000000006
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.65
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 135
# ------------------------------
# C     :  1.7000000000000006
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 136
# ------------------------------
# C     :  1.7000000000000006
# gamma :  0.4
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 137
# ------------------------------
# C     :  1.7000000000000006
# gamma :  0.5
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 138
# ------------------------------
# C     :  1.7000000000000006
# gamma :  0.6
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 139
# ------------------------------
# C     :  1.7000000000000006
# gamma :  0.7000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 140
# ------------------------------
# C     :  1.7000000000000006
# gamma :  0.8
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 141
# ------------------------------
# C     :  1.7000000000000006
# gamma :  0.9
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 142
# ------------------------------
# C     :  1.7000000000000006
# gamma :  1.0
# --------------------
# Rata-rata Akurasi SVM : 0.72
# Rata-rata Waktu eksekusi SVM: 0.01
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 143
# ------------------------------
# C     :  1.7000000000000006
# gamma :  1.1
# --------------------
# Rata-rata Akurasi SVM : 0.73
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 144
# ------------------------------
# C     :  1.7000000000000006
# gamma :  1.2000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.72
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 145
# ------------------------------
# C     :  1.7000000000000006
# gamma :  1.3000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 146
# ------------------------------
# C     :  1.7000000000000006
# gamma :  1.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 147
# ------------------------------
# C     :  1.7000000000000006
# gamma :  1.5000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 148
# ------------------------------
# C     :  1.7000000000000006
# gamma :  1.6
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 149
# ------------------------------
# C     :  1.7000000000000006
# gamma :  1.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 150
# ------------------------------
# C     :  1.7000000000000006
# gamma :  1.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 151
# ------------------------------
# C     :  1.7000000000000006
# gamma :  1.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 152
# ------------------------------
# C     :  1.8000000000000007
# gamma :  0.1
# --------------------
# Rata-rata Akurasi SVM : 0.61
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 153
# ------------------------------
# C     :  1.8000000000000007
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 154
# ------------------------------
# C     :  1.8000000000000007
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 155
# ------------------------------
# C     :  1.8000000000000007
# gamma :  0.4
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 156
# ------------------------------
# C     :  1.8000000000000007
# gamma :  0.5
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 157
# ------------------------------
# C     :  1.8000000000000007
# gamma :  0.6
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 158
# ------------------------------
# C     :  1.8000000000000007
# gamma :  0.7000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 159
# ------------------------------
# C     :  1.8000000000000007
# gamma :  0.8
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 160
# ------------------------------
# C     :  1.8000000000000007
# gamma :  0.9
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 161
# ------------------------------
# C     :  1.8000000000000007
# gamma :  1.0
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 162
# ------------------------------
# C     :  1.8000000000000007
# gamma :  1.1
# --------------------
# Rata-rata Akurasi SVM : 0.73
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 163
# ------------------------------
# C     :  1.8000000000000007
# gamma :  1.2000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 164
# ------------------------------
# C     :  1.8000000000000007
# gamma :  1.3000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 165
# ------------------------------
# C     :  1.8000000000000007
# gamma :  1.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 166
# ------------------------------
# C     :  1.8000000000000007
# gamma :  1.5000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 167
# ------------------------------
# C     :  1.8000000000000007
# gamma :  1.6
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 168
# ------------------------------
# C     :  1.8000000000000007
# gamma :  1.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 169
# ------------------------------
# C     :  1.8000000000000007
# gamma :  1.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 170
# ------------------------------
# C     :  1.8000000000000007
# gamma :  1.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 171
# ------------------------------
# C     :  1.9000000000000008
# gamma :  0.1
# --------------------
# Rata-rata Akurasi SVM : 0.61
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 172
# ------------------------------
# C     :  1.9000000000000008
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 173
# ------------------------------
# C     :  1.9000000000000008
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 174
# ------------------------------
# C     :  1.9000000000000008
# gamma :  0.4
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 175
# ------------------------------
# C     :  1.9000000000000008
# gamma :  0.5
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 176
# ------------------------------
# C     :  1.9000000000000008
# gamma :  0.6
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 177
# ------------------------------
# C     :  1.9000000000000008
# gamma :  0.7000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 178
# ------------------------------
# C     :  1.9000000000000008
# gamma :  0.8
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 179
# ------------------------------
# C     :  1.9000000000000008
# gamma :  0.9
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 180
# ------------------------------
# C     :  1.9000000000000008
# gamma :  1.0
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 181
# ------------------------------
# C     :  1.9000000000000008
# gamma :  1.1
# --------------------
# Rata-rata Akurasi SVM : 0.73
# Rata-rata Waktu eksekusi SVM: 0.01
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 182
# ------------------------------
# C     :  1.9000000000000008
# gamma :  1.2000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 183
# ------------------------------
# C     :  1.9000000000000008
# gamma :  1.3000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 184
# ------------------------------
# C     :  1.9000000000000008
# gamma :  1.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 185
# ------------------------------
# C     :  1.9000000000000008
# gamma :  1.5000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 186
# ------------------------------
# C     :  1.9000000000000008
# gamma :  1.6
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 187
# ------------------------------
# C     :  1.9000000000000008
# gamma :  1.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 188
# ------------------------------
# C     :  1.9000000000000008
# gamma :  1.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 189
# ------------------------------
# C     :  1.9000000000000008
# gamma :  1.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 190
# ------------------------------
# C     :  2.000000000000001
# gamma :  0.1
# --------------------
# Rata-rata Akurasi SVM : 0.61
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 191
# ------------------------------
# C     :  2.000000000000001
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 192
# ------------------------------
# C     :  2.000000000000001
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 193
# ------------------------------
# C     :  2.000000000000001
# gamma :  0.4
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 194
# ------------------------------
# C     :  2.000000000000001
# gamma :  0.5
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 195
# ------------------------------
# C     :  2.000000000000001
# gamma :  0.6
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 196
# ------------------------------
# C     :  2.000000000000001
# gamma :  0.7000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 197
# ...
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 696
# ------------------------------
# C     :  4.600000000000003
# gamma :  1.3000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 697
# ------------------------------
# C     :  4.600000000000003
# gamma :  1.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 698
# ------------------------------
# C     :  4.600000000000003
# gamma :  1.5000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 699
# ------------------------------
# C     :  4.600000000000003
# gamma :  1.6
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 700
# ------------------------------
# C     :  4.600000000000003
# gamma :  1.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 701
# ------------------------------
# C     :  4.600000000000003
# gamma :  1.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 702
# ------------------------------
# C     :  4.600000000000003
# gamma :  1.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.01
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 703
# ------------------------------
# C     :  4.700000000000003
# gamma :  0.1
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 704
# ------------------------------
# C     :  4.700000000000003
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 705
# ------------------------------
# C     :  4.700000000000003
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.72
# Rata-rata Waktu eksekusi SVM: 0.01
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 706
# ------------------------------
# C     :  4.700000000000003
# gamma :  0.4
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 707
# ------------------------------
# C     :  4.700000000000003
# gamma :  0.5
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 708
# ------------------------------
# C     :  4.700000000000003
# gamma :  0.6
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 709
# ------------------------------
# C     :  4.700000000000003
# gamma :  0.7000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 710
# ------------------------------
# C     :  4.700000000000003
# gamma :  0.8
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 711
# ------------------------------
# C     :  4.700000000000003
# gamma :  0.9
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 712
# ------------------------------
# C     :  4.700000000000003
# gamma :  1.0
# --------------------
# Rata-rata Akurasi SVM : 0.73
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 713
# ------------------------------
# C     :  4.700000000000003
# gamma :  1.1
# --------------------
# Rata-rata Akurasi SVM : 0.73
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 714
# ------------------------------
# C     :  4.700000000000003
# gamma :  1.2000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.73
# Rata-rata Waktu eksekusi SVM: 0.01
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 715
# ------------------------------
# C     :  4.700000000000003
# gamma :  1.3000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 716
# ------------------------------
# C     :  4.700000000000003
# gamma :  1.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 717
# ------------------------------
# C     :  4.700000000000003
# gamma :  1.5000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 718
# ------------------------------
# C     :  4.700000000000003
# gamma :  1.6
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 719
# ------------------------------
# C     :  4.700000000000003
# gamma :  1.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 720
# ------------------------------
# C     :  4.700000000000003
# gamma :  1.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 721
# ------------------------------
# C     :  4.700000000000003
# gamma :  1.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 722
# ------------------------------
# C     :  4.800000000000003
# gamma :  0.1
# --------------------
# Rata-rata Akurasi SVM : 0.73
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 723
# ------------------------------
# C     :  4.800000000000003
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 724
# ------------------------------
# C     :  4.800000000000003
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.72
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 725
# ------------------------------
# C     :  4.800000000000003
# gamma :  0.4
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 726
# ------------------------------
# C     :  4.800000000000003
# gamma :  0.5
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 727
# ------------------------------
# C     :  4.800000000000003
# gamma :  0.6
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 728
# ------------------------------
# C     :  4.800000000000003
# gamma :  0.7000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 729
# ------------------------------
# C     :  4.800000000000003
# gamma :  0.8
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 730
# ------------------------------
# C     :  4.800000000000003
# gamma :  0.9
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 731
# ------------------------------
# C     :  4.800000000000003
# gamma :  1.0
# --------------------
# Rata-rata Akurasi SVM : 0.73
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 732
# ------------------------------
# C     :  4.800000000000003
# gamma :  1.1
# --------------------
# Rata-rata Akurasi SVM : 0.73
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 733
# ------------------------------
# C     :  4.800000000000003
# gamma :  1.2000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.73
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 734
# ------------------------------
# C     :  4.800000000000003
# gamma :  1.3000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 735
# ------------------------------
# C     :  4.800000000000003
# gamma :  1.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 736
# ------------------------------
# C     :  4.800000000000003
# gamma :  1.5000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 737
# ------------------------------
# C     :  4.800000000000003
# gamma :  1.6
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 738
# ------------------------------
# C     :  4.800000000000003
# gamma :  1.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 739
# ------------------------------
# C     :  4.800000000000003
# gamma :  1.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 740
# ------------------------------
# C     :  4.800000000000003
# gamma :  1.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 741
# ------------------------------
# C     :  4.900000000000004
# gamma :  0.1
# --------------------
# Rata-rata Akurasi SVM : 0.72
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 742
# ------------------------------
# C     :  4.900000000000004
# gamma :  0.2
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 743
# ------------------------------
# C     :  4.900000000000004
# gamma :  0.30000000000000004
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 744
# ------------------------------
# C     :  4.900000000000004
# gamma :  0.4
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 745
# ------------------------------
# C     :  4.900000000000004
# gamma :  0.5
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 746
# ------------------------------
# C     :  4.900000000000004
# gamma :  0.6
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 747
# ------------------------------
# C     :  4.900000000000004
# gamma :  0.7000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 748
# ------------------------------
# C     :  4.900000000000004
# gamma :  0.8
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 749
# ------------------------------
# C     :  4.900000000000004
# gamma :  0.9
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 750
# ------------------------------
# C     :  4.900000000000004
# gamma :  1.0
# --------------------
# Rata-rata Akurasi SVM : 0.73
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 751
# ------------------------------
# C     :  4.900000000000004
# gamma :  1.1
# --------------------
# Rata-rata Akurasi SVM : 0.73
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 752
# ------------------------------
# C     :  4.900000000000004
# gamma :  1.2000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.73
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 753
# ------------------------------
# C     :  4.900000000000004
# gamma :  1.3000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.71
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 754
# ------------------------------
# C     :  4.900000000000004
# gamma :  1.4000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 755
# ------------------------------
# C     :  4.900000000000004
# gamma :  1.5000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 756
# ------------------------------
# C     :  4.900000000000004
# gamma :  1.6
# --------------------
# Rata-rata Akurasi SVM : 0.70
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 757
# ------------------------------
# C     :  4.900000000000004
# gamma :  1.7000000000000002
# --------------------
# Rata-rata Akurasi SVM : 0.69
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 758
# ------------------------------
# C     :  4.900000000000004
# gamma :  1.8000000000000003
# --------------------
# Rata-rata Akurasi SVM : 0.68
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# iterasi ke- 759
# ------------------------------
# C     :  4.900000000000004
# gamma :  1.9000000000000001
# --------------------
# Rata-rata Akurasi SVM : 0.66
# Rata-rata Waktu eksekusi SVM: 0.00
# Rata-rata Waktu prediksi  SVM: 0.00
# ==============================
# ---------------------------
# gamma terbaik adalah : 0.9
#     C terbaik adalah : 2.4
#              Akurasi : 0.73

# %%
print("---------------------------")
print("   gamma :", round(gamma_range_[index],2))
print("       C :", round(C_range_[index],2))
print(" Akurasi :", round(x, 2))
# Out:
# ---------------------------
#    gamma : 0.4
#        C : 2.6
#  Akurasi : 0.71

# %%
---------------------------
Label
  gamma : 0.5
       C : 1.8
 Akurasi : 0.98
---------------------------
AES
   gamma : 0.3
       C : 3.2
 Akurasi : 0.8
---------------------------
SOKR2
   gamma : 0.4
       C : 2.6
 Akurasi : 0.71

---------------------------
SOKR1
gamma terbaik adalah : 0.9
    C terbaik adalah : 2.4
             Akurasi : 0.73

# %%
# cSVM = svm.SVC(kernel='rbf', gamma=0.2, C=2.3)
cSVM = svm.SVC(kernel='rbf', gamma=round(gamma_range_[index],2), C=round(C_range_[index],2))
cSVM = cSVM.fit(X, y)
dump(cSVM, 'model/SVM_B.joblib')
# Out:
# ['model/SVM_B.joblib']
